# %% [markdown]
# <a href="https://colab.research.google.com/github/MariuszGrecki/Machine_learning_muller_guido/blob/main/Modele_liniowe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mglearn
import sys
import pandas as pd
import matplotlib
import numpy as np
import scipy as sp
import IPython
import sklearn
import mglearn
import matplotlib.pyplot as plt
print("python version: {}".format(sys.version))
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 581.4/581.4 kB 2.8 MB/s eta 0:00:00
# ...
# python version: 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]

# %%
mglearn.plots.plot_linear_regression_wave()
# Out:
# w[0]: 0.393906  b: -0.031804

# %% [markdown]
# # Regresja liniowa

# %%
from sklearn.linear_model import LinearRegression
data = mglearn.datasets.make_wave(n_samples = 60)

# %%
data
# Out:
# (array([[-0.75275929],
#         [ 2.70428584],
#         [ 1.39196365],
#         [ 0.59195091],
#         [-2.06388816],
#         [-2.06403288],
#         [-2.65149833],
#         [ 2.19705687],
#         [ 0.60669007],
#         [ 1.24843547],
#         [-2.87649303],
#         [ 2.81945911],
#         [ 1.99465584],
#         [-1.72596534],
#         [-1.9090502 ],
#         [-1.89957294],
#         [-1.17454654],
#         [ 0.14853859],
#         [-0.40832989],
#         [-1.25262516],
#         [ 0.67111737],
#         [-2.16303684],
#         [-1.24713211],
#         [-0.80182894],
#         [-0.26358009],
#         [ 1.71105577],
#         [-1.80195731],
#         [ 0.08540663],
#         [ 0.55448741],
#         [-2.72129752],
#         [ 0.64526911],
#         [-1.97685526],
#         [-2.60969044],
#         [ 2.69331322],
#         [ 2.7937922 ],
#         [ 1.85038409],
#         [-1.17231738],
#         [-2.41396732],
#         [ 1.10539816],
#         [-0.35908504],
# ...

# %%
X, y = mglearn.datasets.make_wave(n_samples=100)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
lr = LinearRegression().fit(X_train, y_train)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(8, 6))
plt.title('regresja liniowa')
plt.xlabel('cecha x')
plt.ylabel('zmienna docelowa')
plt.scatter(X, y, label='cecha x')
plt.legend()
plt.plot()
# Out:
# []

# %%
y_pred = lr.predict(X)

# %%
plt.figure(figsize=(8, 6))
plt.title('regresja liniowa')
plt.xlabel('cecha x')
plt.ylabel('zmienna docelowa')
plt.scatter(X, y, label='cecha x')
plt.plot(X, y_pred, color='red', label='model')
plt.legend()
plt.plot()
# Out:
# []

# %%
lr.coef_
# Out:
# array([0.40443939])

# %%
lr.intercept_
# Out:
# -0.02256802817336538

# %%
lr.score(X_train, y_train)
# Out:
# 0.5932911361660249

# %%
lr.score(X_test, y_test)
# Out:
# 0.6599448011276341

# %%
boston = mglearn.datasets.load_extended_boston()

# %%
boston
# Out:
# (array([[0.00000000e+00, 1.80000000e-01, 6.78152493e-02, ...,
#          1.00000000e+00, 8.96799117e-02, 8.04248656e-03],
#         [2.35922539e-04, 0.00000000e+00, 2.42302053e-01, ...,
#          1.00000000e+00, 2.04470199e-01, 4.18080621e-02],
#         [2.35697744e-04, 0.00000000e+00, 2.42302053e-01, ...,
#          9.79579831e-01, 6.28144504e-02, 4.02790570e-03],
#         ...,
#         [6.11892474e-04, 0.00000000e+00, 4.20454545e-01, ...,
#          1.00000000e+00, 1.07891832e-01, 1.16406475e-02],
#         [1.16072990e-03, 0.00000000e+00, 4.20454545e-01, ...,
#          9.82676920e-01, 1.29930407e-01, 1.71795127e-02],
#         [4.61841693e-04, 0.00000000e+00, 4.20454545e-01, ...,
#          1.00000000e+00, 1.69701987e-01, 2.87987643e-02]]),
#  array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#         18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#         15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
# ...

# %%
X, y = mglearn.datasets.load_extended_boston()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
lr = LinearRegression().fit(X_train, y_train)

# %%
lr.score(X_train, y_train)
# Out:
# 0.9520519609032727

# %%
lr.score(X_test, y_test)
# Out:
# 0.6074721959665794

# %% [markdown]
# # Regresja grzbietowa

# %%
from sklearn.linear_model import Ridge
ridge = Ridge().fit(X_train, y_train)
print(ridge.score(X_train, y_train))
print(ridge.score(X_test, y_test))
# Out:
# 0.8857966585170941
# 0.7527683481744752

# %%
ridge10 = Ridge(alpha=10).fit(X_train, y_train)
print(ridge10.score(X_train, y_train))
print(ridge10.score(X_test, y_test))
# Out:
# 0.7882787115369614
# 0.6359411489177309

# %%
ridge01 = Ridge(alpha=0.1).fit(X_train, y_train)
print(ridge01.score(X_train, y_train))
print(ridge01.score(X_test, y_test))
# Out:
# 0.9282273685001993
# 0.7722067936479827

# %%
mglearn.plots.plot_ridge_n_samples()

# %% [markdown]
# # Model Lasso

# %%
from sklearn.linear_model import Lasso
lasso = Lasso().fit(X_train, y_train)
print(lasso.score(X_train, y_train))
print(lasso.score(X_test, y_test))
print(np.sum(lasso.coef_ != 0)) #liczba użytych cech
# Out:
# 0.29323768991114607
# 0.20937503255272294
# 4

# %%
lasso001 = Lasso(alpha=0.01, max_iter=100000).fit(X_train, y_train)
print(lasso001.score(X_train, y_train))
print(lasso001.score(X_test, y_test))
print(np.sum(lasso001.coef_ != 0)) #liczba uzytych cech
# Out:
# 0.8962226511086497
# 0.7656571174549982
# 33

# %%
lasso00001 = Lasso(alpha=0.0001, max_iter=100000).fit(X_train, y_train)
print(lasso00001.score(X_train, y_train))
print(lasso00001.score(X_test, y_test))
print(np.sum(lasso00001.coef_ != 0)) #liczba uzytych cech
# Out:
# 0.9507158754515463
# 0.6437467421272821
# 96

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
X, y = mglearn.datasets.make_forge()
fig, axes = plt.subplots(1,2,figsize=(10,3))
for model, ax in zip([LinearSVC(), LogisticRegression()], axes):
  clf = model.fit(X, y)
  mglearn.plots.plot_2d_separator(clf, X, fill=False, eps=0.5, ax=ax, alpha=.7)
  mglearn.discrete_scatter(X[:, 0], X[:, 1], y, ax=ax)
  ax.set_title("{}".format(clf.__class__.__name__))
  ax.set_xlabel("Cecha 0")
  ax.set_ylabel("Cecha 1")
axes[0].legend()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
# w przypadku LogisticRegression i LinearSVC parametr kompromisu określa się C, Niski C algorytmy beda próbowały dostować się do wiekszości punktów danych, gdy wyższa C podkresla znaczenie prwidłowego sklasyfikowania każdego pojedynczego punktu danych.
mglearn.plots.plot_linear_svc_regularization()

# %%
from sklearn.datasets import load_breast_cancer
cancer = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(
  cancer.data, cancer.target, stratify=cancer.target, random_state=42
)
logreg = LogisticRegression().fit(X_train, y_train) #domyslnie jest 1
print(logreg.score(X_train, y_train))
print(logreg.score(X_test, y_test))
# Out:
# 0.9460093896713615
# 0.958041958041958
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
logreg = LogisticRegression(C=100000).fit(X_train, y_train)
print(logreg.score(X_train, y_train))
print(logreg.score(X_test, y_test))
# Out:
# 0.9436619718309859
# 0.965034965034965
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
logreg = LogisticRegression(C=100000).fit(X_train, y_train)
print(logreg.score(X_train, y_train))
print(logreg.score(X_test, y_test))

# %% [markdown]
# # Modele liniowe do klasyfikacji wieloklasowej

# %%
from sklearn.datasets import make_blobs

X, y = make_blobs(random_state=42)
mglearn.discrete_scatter(X[:, 0], X[:, 1], y)
plt.xlabel("cecha 0")
plt.ylabel("Cecha 1")
plt.legend(["klasa 0", "Klasa 1", "Klasa 2"])

# %%
linear_svm = LinearSVC().fit(X, y)
print(linear_svm.coef_.shape)
print(linear_svm.intercept_.shape)
# Out:
# (3, 2)
# (3,)

# %%
mglearn.discrete_scatter(X[:, 0], X[:, 1], y)
line = np.linspace(-15,15)
for coef, intercept, color in zip(linear_svm.coef_, linear_svm.intercept_, ['b', 'r', 'g']):
  plt.plot(line, -(line * coef[0] + intercept) / coef[1], c=color)
plt.ylim(-10,15)
plt.xlim(-10,8)
plt.xlabel("cecha O")
plt.ylabel("Cecha 1")
plt.legend(['Klasa 0', 'Klasa 1', 'Klasa 2', 'Linia klasy 0', 'Linia klasy 1', 'Linia klasy 2'], loc=(1.01, 0.3))
