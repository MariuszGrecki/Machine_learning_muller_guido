# %% [markdown]
# <a href="https://colab.research.google.com/github/MariuszGrecki/Machine_learning_muller_guido/blob/main/Przetwarzanie_wstepne.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mglearn
import sys
import pandas as pd
import matplotlib
import numpy as np
import scipy as sp
import IPython
import sklearn
import mglearn
import matplotlib.pyplot as plt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 581.4/581.4 kB 3.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Skalowanie

# %% [markdown]
# Skalowanie jest sposobem na przetwarzanie wstępne danych, chodzi o to żeby zbiór dopasować  w ten sposób aby dane ułożyć na wykresie X, Y jak najbliżej punktu 0,0 . Dzięki czemu modele łatwiej sobie radzą z obliczeniami. Możemy do tego użyć **StandardScaler, MinMaxScaler, RobustScaler** nastepnie np.:
#
# scaler = MinMaxScaler()
#
# scaler.fit(X_train)
#
# X_train_scaled = sclaer.transform(X_train)
#
# X_test_scaled = sclaer.transform(X_test)
#
# svm.fit(X_train_scaled, y_train)
#
# Ważne jest aby skalowanie nie odbywało się oddzielnie dla zbioru testowego i uczącego.

# %% [markdown]
# # Analiza głównych komponentów
#
# Obróceniu zbioru danych

# %%
mglearn.plots.plot_pca_illustration()

# %% [markdown]
# # Zastosowanie PCA

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import StandardScaler
cancer = load_breast_cancer()
scaler = StandardScaler()
scaler.fit(cancer.data)
X_scaled = scaler.transform(cancer.data)

from sklearn.decomposition import PCA
pca = PCA(n_components = 2)
pca.fit(X_scaled)
X_pca = pca.transform(X_scaled)

plt.figure(figsize=(8,8))
mglearn.discrete_scatter(X_pca[:, 0], X_pca[:, 1], cancer.target)
plt.legend(cancer.target_names, loc="best")
plt.gca().set_aspect("equal")
plt.xlabel("Pierwszy główny komponenet")
plt.ylabel("Drugi główny komponent")
# Out:
# Text(0, 0.5, 'Drugi główny komponent')
